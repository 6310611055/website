# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
df = pd.read_csv('../../Dataset/for training/filter_feature_train_modeling.csv').drop(columns=['Unnamed: 0'])
df['Id'] = ['condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'control', 'control',
            'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control']
df
# Out:
#     5days_day_time_activity  work  afftype  madrs1         Id
# 0                  228824.0     2        2      19  condition
# 1                  239278.2     2        1      24  condition
# 2                  317726.0     2        2      24  condition
# 3                  194298.2     1        2      20  condition
# 4                  200302.2     2        2      26  condition
# 5                  240767.8     2        2      18  condition
# 6                  335598.2     1        1      24  condition
# 7                  284320.6     2        2      20  condition
# 8                  203120.0     2        1      26  condition
# 9                  482765.0     2        2      28  condition
# 10                 153494.6     2        2      24  condition
# 11                 228420.4     2        1      25  condition
# 12                 291661.6     2        1      18  condition
# 13                  72237.4     2        1      28  condition
# ...

# %%
sns.boxplot(data=df, x='Id', y='5days_day_time_activity')
plt.title('')
plt.grid()
plt.show()

# %%
df1 = pd.read_csv('../../Dataset/5_day_correlation.csv').drop(columns=['Unnamed: 0'])
df1['Id'] = ['condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'condition', 'control', 'control',
            'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control', 'control']
df1
# Out:
#     gender  age  afftype  melanch  inpatient  edu  marriage  work  madrs1  \
# 0        2   37      2.0      2.0        2.0    8       1.0   2.0    19.0
# 1        2   42      1.0      2.0        2.0    8       2.0   2.0    24.0
# 2        1   47      2.0      2.0        2.0    8       2.0   2.0    24.0
# 3        2   27      2.0      2.0        2.0   13       1.0   1.0    20.0
# 4        2   52      2.0      2.0        2.0   13       2.0   2.0    26.0
# 5        1   37      2.0      2.0        2.0    8       1.0   2.0    18.0
# 6        1   22      1.0      2.0        2.0   13       2.0   1.0    24.0
# 7        2   27      2.0      2.0        2.0   13       1.0   2.0    20.0
# 8        2   47      1.0      2.0        2.0    8       1.0   2.0    26.0
# 9        2   47      2.0      2.0        2.0    8       1.0   2.0    28.0
# 10       1   47      2.0      2.0        2.0    8       1.0   2.0    24.0
# 11       2   42      1.0      2.0        2.0    8       2.0   2.0    25.0
# ...

# %%
sns.boxplot(data=df1, x='Id', y='5days_sleep_time_activity')
plt.title('')
plt.grid()
plt.show()

# %%
df2 = df1.loc[(df['Id'] == 'condition')].sort_values(by=['5days_day_time_activity'])
df2
# Out:
#     gender  age  afftype  melanch  inpatient  edu  marriage  work  madrs1  \
# 17       2   42      3.0      2.0        2.0   13       2.0   2.0    18.0
# 13       1   62      1.0      2.0        2.0    8       2.0   2.0    28.0
# 19       1   32      2.0      1.0        1.0    8       1.0   2.0    27.0
# 16       1   52      1.0      2.0        2.0    8       1.0   2.0    17.0
# 20       2   37      2.0      2.0        1.0    8       2.0   2.0    26.0
# 10       1   47      2.0      2.0        2.0    8       1.0   2.0    24.0
# 14       2   57      2.0      2.0        2.0   13       1.0   1.0    14.0
# 21       1   67      2.0      2.0        1.0    8       2.0   2.0    29.0
# 18       2   52      2.0      2.0        1.0   18       2.0   2.0    26.0
# 3        2   27      2.0      2.0        2.0   13       1.0   1.0    20.0
# 4        2   52      2.0      2.0        2.0   13       2.0   2.0    26.0
# 8        2   47      1.0      2.0        2.0    8       1.0   2.0    26.0
# ...
