# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

# %%
data = pd.read_csv('filling missing/scores_full.csv')
data = data.iloc[:,3:] 
# days	gender	age	afftype	melanch	inpatient	edu	marriage	work	madrs1

data.drop(["Unnamed: 12"], axis=1, inplace=True)
data.fillna(0, inplace = True)
data
# Out:
#     gender  age  afftype  melanch  inpatient   edu  marriage  work  madrs1
# 0        2   37        2        2          2   8.0         1     2      19
# 1        2   42        1        2          2   8.0         2     2      24
# 2        1   47        2        2          2   8.0         2     2      24
# 3        2   27        2        2          2  13.0         1     1      20
# 4        2   52        2        2          2  13.0         2     2      26
# 5        1   37        2        2          2   8.0         1     2      18
# 6        1   22        1        2          2  13.0         2     1      24
# 7        2   27        2        2          2  13.0         1     2      20
# 8        2   47        1        2          2   8.0         1     2      26
# 9        2   47        2        2          2   8.0         1     2      28
# 10       1   47        2        2          2   8.0         1     2      24
# ...

# %%
corr = data.corr()
plt.figure(figsize=(16, 6))
heatmap = sns.heatmap(corr, vmin=-1, vmax=1, annot=True, cmap="YlOrBr", linewidths=.5)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
heatmap
# Out:
# <AxesSubplot:title={'center':'Correlation Heatmap'}>
